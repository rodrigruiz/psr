# %%
import pandas as pd
file = '/home/wecapstor3/capn/mppi083h/share/PID/temp_file_test_v7.h5'
df = pd.read_hdf(file, 'summary')

# %%
print(df.__dict__)
# Out:
# {'_is_copy': None, '_mgr': BlockManager
# Items: Index(['tau_decay_channel', 'tau_decay_invisible_energy', 'run_id', 'energy',
#        'cos_zenith_true', 'bjorken_y_true', 'pdgid', 'w2', 'is_cc', 'n_gen',
#        'trigger_mask', 'mc_sphericity', 'mc_aplanarity', 'mc_e_sphericity',
#        'mc_e_aplanarity', 'mc_p_sphericity', 'mc_p_aplanarity',
#        'mc_lin_sphericity', 'mc_lin_aplanarity', 'mc_e_lin_sphericity',
#        'mc_e_lin_aplanarity', 'mc_p_lin_sphericity', 'mc_p_lin_aplanarity',
#        'mc_lin_c', 'mc_lin_d', 'mc_e_lin_c', 'mc_e_lin_d', 'mc_p_lin_c',
#        'mc_p_lin_d', 'mc_c', 'mc_d', 'mc_e_c', 'mc_e_d', 'mc_p_c', 'mc_p_d',
#        'h0', 'h1', 'h2', 'h3', 'h4', 'sphericity_r1', 'sphericity_r2',
#        'aplanarity_r1', 'aplanarity_r2', 'c_r1', 'c_r2', 'd_r1', 'd_r2',
#        'q_mc', 'q', 'q_trig', 'mc_hit_sphericity', 'mc_hit_aplanarity',
#        'mc_hit_track_angle', 'mc_hit_track_angle_median',
#        'mc_hit_track_angle_max'],
#       dtype='object')
# ...

# %%
muon_rootpath = '/home/hpc/capn/mppi104h/wecapstor3/out/ARCA/KM3NeT_00000133/v8.1/reco/muon/mcv8.1.gsg_numu-CCHEDIS_1e2-1e8GeV.sirene.jterbr00013288.jchain.aashower.1.root'
